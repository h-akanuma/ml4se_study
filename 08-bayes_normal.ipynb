# %%
# ベイズ推定による正規分布の推定

require 'rubystats/normal_distribution'
require 'nyaplot'

class Array
  def mean
    self.inject(:+) / self.size.to_f
  end
end

def normal_rand(mu = 0, sigma = 1.0)
  random = Random.new
  (Math.sqrt(-2 * Math.log(random.rand)) * Math.sin(2 * Math::PI * random.rand) * sigma) + mu
end

DATA_COUNTS = [2, 4, 10, 100]

# 真の分布
MU_TRUE = 2.0
BETA_TRUE = 1.0

# 事前分布
MU_0 = -2.0
BETA_0 = 1.0

ds = 100.times.map do
  normal_rand(MU_TRUE, 1.0 / BETA_TRUE)
end

fig1 = Nyaplot::Frame.new
fig2 = Nyaplot::Frame.new

DATA_COUNTS.each_with_index do |n, c|
  train_set = ds[0..n-1]
  mu_ML = train_set.mean
  mu_N = (BETA_TRUE * mu_ML + BETA_0 * MU_0 / n) / (BETA_TRUE + BETA_0 / n)
  beta_N = BETA_0 + n * BETA_TRUE

# 平均μの推定結果を表示
  plot = Nyaplot::Plot.new
  linex = (-10..10).step(0.01).to_a

  # 平均μの確率分布
  sigma = 1.0 / beta_N
  mu_est = Rubystats::NormalDistribution.new(mu_N, Math.sqrt(sigma))
  label = "mu_N=%.2f var=%.2f" % [mu_N, sigma]
  liney = linex.map {|x| mu_est.pdf(x) }
  line = plot.add(:line, linex, liney)
  line.title(label)
  line.color('red')

  # トレーニングセットを表示
  scatter = plot.add(:scatter, train_set, [0.2] * n)
  scatter.title('train_set')
  scatter.color('blue')

  plot.configure do
    x_label("N=#{n}")
    y_label('')
    xrange([-5, 5])
    yrange([0, liney.max * 1.1])
    legend(true)
    height(300)
    width(490)
  end

  fig1.add(plot)

# 次に得られるデータの推定分布を表示
  plot = Nyaplot::Plot.new
  
  # 真の分布を表示
  orig = Rubystats::NormalDistribution.new(MU_TRUE, Math.sqrt(1.0 / BETA_TRUE))
  liney = linex.map {|x| orig.pdf(x)}
  y_max = liney.max * 1.1
  line = plot.add(:line, linex, liney)
  line.title('original')
  line.color('green')
  
  # 推定分布を表示
  sigma = 1.0 / BETA_TRUE + 1.0 / beta_N
  mu_est = Rubystats::NormalDistribution.new(mu_N, Math.sqrt(sigma))
  label = "mu_N=%.2f var=%.2f" % [mu_N, sigma]
  liney = linex.map {|x| mu_est.pdf(x) }
  line = plot.add(:line, linex, liney)
  line.title(label)
  line.color('red')
  
  # トレーニングセットを表示
  scatter = plot.add(:scatter, train_set, train_set.map {|x| orig.pdf(x) })
  scatter.title('train_set')
  scatter.color('blue')

  plot.configure do
    x_label("N=#{n}")
    y_label('')
    xrange([-5, 5])
    yrange([0, y_max])
    legend(true)
    height(300)
    width(490)
  end

  fig2.add(plot)
end

fig1.show
fig2.show
# Out:
# <main>:16: warning: already initialized constant DATA_COUNTS
# <main>:16: warning: previous definition of DATA_COUNTS was here
# #<Nyaplot::Frame:0x007fc8c34b1020 @properties={:panes=>[#<Nyaplot::Plot:0x007fc8c34b0940 @properties={:diagrams=>[#<Nyaplot::Diagram:0x007fc8c2f26380 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1", :title=>"mu_N=0.95 var=0.33", :color=>"red"}, :data=>"2771ba9e-adef-427d-8c1a-fa50bf634619"}, @xrange=[-10.0, 10.0], @yrange=[5.653863506405245e-79, 0.6909857512157087]>, #<Nyaplot::Diagram:0x007fc8c2f1fb20 @properties={:type=>:scatter, :options=>{:x=>"data0", :y=>"data1", :title=>"train_set", :color=>"blue"}, :data=>"af8c48b9-f78d-4f7b-954f-1659efeecdf9"}, @xrange=[2.0070888776497497, 2.8382076659724125], @yrange=[0.2, 0.2]>], :options=>{:x_label=>"N=2", :y_label=>"", :xrange=>[-5, 5], :yrange=>[0, 0.7600843263372796], :legend=>true, :height=>300, :width=>490, :zoom=>true}}>, #<Nyaplot::Plot:0x007fc8c0930e00 @properties={:diagrams=>[#<Nyaplot::Diagram:0x007fc8c454f490 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1", :title=>"mu_N=1.35 var=0.20", :color=>"red"}, :data=>"90170e9d-5391-4cbc-a916-6c32bf22c2b8"}, @xrange=[-10.0, 10.0], @yrange=[1.0916319617045696e-140, 0.8920546026531794]>, #<Nyaplot::Diagram:0x007fc8c454e2c0 @properties={:type=>:scatter, :options=>{:x=>"data0", :y=>"data1", :title=>"train_set", :color=>"blue"}, :data=>"92e6a958-878a-4a11-af80-6c8a1455935e"}, @xrange=[0.6430509191045388, 3.270794501636178], @yrange=[0.2, 0.2]>], :options=>{:x_label=>"N=4", :y_label=>"", :xrange=>[-5, 5], :yrange=>[0, 0.9812600629184974], :legend=>true, :height=>300, :width=>490, :zoom=>true}}>, #<Nyaplot::Plot:0x007fc8c4e8a8c0 @properties={:diagrams=>[#<Nyaplot::Diagram:0x007fc8c5826d70 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1", :title=>"mu_N=1.45 var=0.09", :color=>"red"}, :data=>"64a5e367-8566-46b5-81f4-8ae94978c7f3"}, @xrange=[-10.0, 10.0], @yrange=[7.3442048545e-314, 1.3231167279604636]>, #<Nyaplot::Diagram:0x007fc8c5825010 @properties={:type=>:scatter, :options=>{:x=>"data0", :y=>"data1", :title=>"train_set", :color=>"blue"}, :data=>"5523513d-0613-44f7-a628-8282f559505a"}, @xrange=[0.5123635802860078, 3.270794501636178], @yrange=[0.2, 0.2]>], :options=>{:x_label=>"N=10", :y_label=>"", :xrange=>[-5, 5], :yrange=>[0, 1.4554284007565101], :legend=>true, :height=>300, :width=>490, :zoom=>true}}>, #<Nyaplot::Plot:0x007fc8c4d95b90 @properties={:diagrams=>[#<Nyaplot::Diagram:0x007fc8c4f16ca8 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1", :title=>"mu_N=1.84 var=0.01", :color=>"red"}, :data=>"aa6f4b52-c844-4a01-896d-be0a697fe9ed"}, @xrange=[-10.0, 10.0], @yrange=[0.0, 4.009240639763099]>, #<Nyaplot::Diagram:0x007fc8c4d40078 @properties={:type=>:scatter, :options=>{:x=>"data0", :y=>"data1", :title=>"train_set", :color=>"blue"}, :data=>"eabe4990-c5a0-40ab-bae5-7db48c9ff58d"}, @xrange=[-0.5826247758446401, 4.127776332126652], @yrange=[0.2, 0.2]>], :options=>{:x_label=>"N=100", :y_label=>"", :xrange=>[-5, 5], :yrange=>[0, 4.410164703739409], :legend=>true, :height=>300, :width=>490, :zoom=>true}}>], :data=>{"2771ba9e-adef-427d-8c1a-fa50bf634619"=>#<Nyaplot::DataFrame:0x007fc8c349ad48 @name="2771ba9e-adef-427d-8c1a-fa50bf634619", @rows=[{:data0=>-10.0, :data1=>5.653863506405245e-79}, {:data0=>-9.99, :data1=>7.851009194568679e-79}, {:data0=>-9.98, :data1=>1.0898716704644286e-78}, {:data0=>-9.97, :data1=>1.5124985030861273e-78}, {:data0=>-9.96, :data1=>2.098380562805851e-78}, {:data0=>-9.95, :data1=>2.910336912868597e-78}, {:data0=>-9.94, :data1=>4.035264364969654e-78}, {:data0=>-9.93, :data1=>5.593329812897347e-78}, {:data0=>-9.92, :data1=>7.750658042019474e-78}, {:data0=>-9.91, :data1=>1.073683887526527e-77}, {:data0=>-9.9, :data1=>1.486907688134054e-77}, {:data0=>-9.89, :data1=>2.058549382968105e-77}, {:data0=>-9.88, :data1=>2.8491038811159582e-77}, {:data0=>-9.87, :data1=>3.942075978307813e-77}, {:data0=>-9.86, :data1=>5.452697541862975e-77}, {:data0=>-9.85, :data1=>7.539933885408098e-77}, {:data0=>-9.84, :data1=>1.0423015385890871e-76}, {:data0=>-9.83, :data1=>1.440419299406 ...
# #<Nyaplot::Frame:0x007fc8c34b0dc8 @properties={:panes=>[#<Nyaplot::Plot:0x007fc8c2f1da00 @properties={:diagrams=>[#<Nyaplot::Diagram:0x007fc8c1b192e8 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1", :title=>"original", :color=>"green"}, :data=>"e6b7c86a-566b-41e3-9f2b-29e579983508"}, @xrange=[-10.0, 10.0], @yrange=[2.1463837356630602e-32, 0.39894228040143265]>, #<Nyaplot::Diagram:0x007fc8c082d468 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1", :title=>"mu_N=0.95 var=1.33", :color=>"red"}, :data=>"31670006-e687-4cba-b90b-0eed2ab82473"}, @xrange=[-10.0, 10.0], @yrange=[1.0391048075499427e-20, 0.3454938310050249]>, #<Nyaplot::Diagram:0x007fc8c080fad0 @properties={:type=>:scatter, :options=>{:x=>"data0", :y=>"data1", :title=>"train_set", :color=>"blue"}, :data=>"7442a4f1-926d-4315-86cb-e23f175e7b5f"}, @xrange=[2.0070888776497497, 2.8382076659724125], @yrange=[0.28076575234499057, 0.3989322566664564]>], :options=>{:x_label=>"N=2", :y_label=>"", :xrange=>[-5, 5], :yrange=>[0, 0.43883650844157596], :legend=>true, :height=>300, :width=>490, :zoom=>true}}>, #<Nyaplot::Plot:0x007fc8c454d820 @properties={:diagrams=>[#<Nyaplot::Diagram:0x007fc8c2a171c8 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1", :title=>"original", :color=>"green"}, :data=>"aaeb31c2-2654-4a06-a7b6-1a1db3be43e4"}, @xrange=[-10.0, 10.0], @yrange=[2.1463837356630602e-32, 0.39894228040143265]>, #<Nyaplot::Diagram:0x007fc8c4ecc5b8 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1", :title=>"mu_N=1.35 var=1.20", :color=>"red"}, :data=>"3ca40f4c-ee0a-44dd-bf3f-a5e043c396d6"}, @xrange=[-10.0, 10.0], @yrange=[1.748234307443825e-24, 0.3641823029182968]>, #<Nyaplot::Diagram:0x007fc8c4e8b3b0 @properties={:type=>:scatter, :options=>{:x=>"data0", :y=>"data1", :title=>"train_set", :color=>"blue"}, :data=>"126cfa2d-150f-416d-ae50-0b6d3f580a2b"}, @xrange=[0.6430509191045388, 3.270794501636178], @yrange=[0.15888192903878576, 0.3989322566664564]>], :options=>{:x_label=>"N=4", :y_label=>"", :xrange=>[-5, 5], :yrange=>[0, 0.43883650844157596], :legend=>true, :height=>300, :width=>490, :zoom=>true}}>, #<Nyaplot::Plot:0x007fc8c58242c8 @properties={:diagrams=>[#<Nyaplot::Diagram:0x007fc8c4f66f78 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1", :title=>"original", :color=>"green"}, :data=>"44771dc5-833b-4801-98cb-0087d58354fe"}, @xrange=[-10.0, 10.0], @yrange=[2.1463837356630602e-32, 0.39894228040143265]>, #<Nyaplot::Diagram:0x007fc8c4dd8670 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1", :title=>"mu_N=1.45 var=1.09", :color=>"red"}, :data=>"aa276eaa-d5c6-47c0-8da7-7c621b289494"}, @xrange=[-10.0, 10.0], @yrange=[3.001769333899822e-27, 0.38195754916804736]>, #<Nyaplot::Diagram:0x007fc8c4d96928 @properties={:type=>:scatter, :options=>{:x=>"data0", :y=>"data1", :title=>"train_set", :color=>"blue"}, :data=>"00377939-21b8-4940-a95e-8c08862a83c0"}, @xrange=[0.5123635802860078, 3.270794501636178], @yrange=[0.1319318745080092, 0.3989322566664564]>], :options=>{:x_label=>"N=10", :y_label=>"", :xrange=>[-5, 5], :yrange=>[0, 0.43883650844157596], :legend=>true, :height=>300, :width=>490, :zoom=>true}}>, #<Nyaplot::Plot:0x007fc8c3b3f568 @properties={:diagrams=>[#<Nyaplot::Diagram:0x007fc8c3f6b920 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1", :title=>"original", :color=>"green"}, :data=>"27a55591-0e7f-46ef-909e-429e5229c35b"}, @xrange=[-10.0, 10.0], @yrange=[2.1463837356630602e-32, 0.39894228040143265]>, #<Nyaplot::Diagram:0x007fc8c4ff6a10 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1", :title=>"mu_N=1.84 var=1.01", :color=>"red"}, :data=>"5983fccf-4e69-4cae-8256-59061362098e"}, @xrange=[-10.0, 10.0], @yrange=[2.8806359344001078e-31, 0.3969817868834835]>, #<Nyaplot::Diagram:0x007fc8c55862c8 @properties={:type=>:scatter, :options=>{:x=>"data0", :y=>"data1", :title=>"train_set", :color=>"blue"}, :data=>"3304ca09-6207-45a3-9c05-f83c5a21745b"}, @xrange=[-0.5826247758446401, 4.12777633212 ...
